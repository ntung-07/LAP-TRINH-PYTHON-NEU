# %%
# Bài 2:
def check_String(inputString: str) -> bool:
    sortedString = "".join(sorted(inputString))
    
    for i in range(len(sortedString)):
        if i > 0 and sortedString[i] == first_char:
            count += 1
            maximum = max(maximum, count)
            

            
print(check_String("bbbaacdafe"))
print(check_String("aabbb"))
print(check_String("bbc"))
# Out:
# False
# False
# True
